# %%
import pandas as pd

# %%
names1880 = pd.read_csv('data/babynames/yob1880.txt', names=['name', 'sex', 'births'])
names1880.head()
# Out:
#         name sex  births
# 0       Mary   F    7065
# 1       Anna   F    2604
# 2       Emma   F    2003
# 3  Elizabeth   F    1939
# 4     Minnie   F    1746

# %%
names1880.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    2000 non-null   object
#  1   sex     2000 non-null   object
#  2   births  2000 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 47.0+ KB

# %%
names1880.groupby('sex').births.sum()
# Out:
# sex
# F     90993
# M    110493
# Name: births, dtype: int64

# %%
from tqdm.notebook import tqdm

years = range(1880, 2011)
pieces = []
columns = ['name', 'sex', 'births']

for year in tqdm(years):
    path = 'data/babynames/yob%d.txt' % year
    frame = pd.read_csv(path, names=columns)
    frame['year'] = year
    pieces.append(frame)

names = pd.concat(pieces, ignore_index=True)
# Out:
#   0%|          | 0/131 [00:00<?, ?it/s]

# %%
names
# Out:
#               name sex  births  year
# 0             Mary   F    7065  1880
# 1             Anna   F    2604  1880
# 2             Emma   F    2003  1880
# 3        Elizabeth   F    1939  1880
# 4           Minnie   F    1746  1880
# ...            ...  ..     ...   ...
# 1690779    Zymaire   M       5  2010
# 1690780     Zyonne   M       5  2010
# 1690781  Zyquarius   M       5  2010
# 1690782      Zyran   M       5  2010
# 1690783      Zzyzx   M       5  2010
#
# [1690784 rows x 4 columns]

# %%
total_births = names.pivot_table('births', index='year', columns='sex', aggfunc='sum')
total_births.head()
# Out:
# sex        F       M
# year
# 1880   90993  110493
# 1881   91955  100748
# 1882  107851  113687
# 1883  112322  104632
# 1884  129021  114445

# %%
total_births.tail()
# Out:
# sex         F        M
# year
# 2006  1896468  2050234
# 2007  1916888  2069242
# 2008  1883645  2032310
# 2009  1827643  1973359
# 2010  1759010  1898382

# %%
import matplotlib.pyplot as plt

total_births.plot(title='Total births by sex and year', figsize=(13, 7))
plt.show()

# %%
names.head()
# Out:
#         name sex  births  year
# 0       Mary   F    7065  1880
# 1       Anna   F    2604  1880
# 2       Emma   F    2003  1880
# 3  Elizabeth   F    1939  1880
# 4     Minnie   F    1746  1880

# %%
def add_group(group):
    group['prop'] = group.births / group.births.sum()
    return group

names = names.groupby(['year', 'sex'], as_index=False).apply(add_group)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_2948\2410559541.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   names = names.groupby(['year', 'sex'], as_index=False).apply(add_group)

# %%
names
# Out:
#                   name sex  births  year      prop
# 0   0             Mary   F    7065  1880  0.077643
#     1             Anna   F    2604  1880  0.028618
#     2             Emma   F    2003  1880  0.022013
#     3        Elizabeth   F    1939  1880  0.021309
#     4           Minnie   F    1746  1880  0.019188
# ...                ...  ..     ...   ...       ...
# 261 1690779    Zymaire   M       5  2010  0.000003
#     1690780     Zyonne   M       5  2010  0.000003
#     1690781  Zyquarius   M       5  2010  0.000003
#     1690782      Zyran   M       5  2010  0.000003
#     1690783      Zzyzx   M       5  2010  0.000003
#
# [1690784 rows x 5 columns]

# %%
names.groupby(['year', 'sex']).prop.sum()
# Out:
# year  sex
# 1880  F      1.0
#       M      1.0
# 1881  F      1.0
#       M      1.0
# 1882  F      1.0
#             ...
# 2008  M      1.0
# 2009  F      1.0
#       M      1.0
# 2010  F      1.0
#       M      1.0
# Name: prop, Length: 262, dtype: float64

# %%
def get_top1000(group):
    return group.sort_values(by='births', ascending=False)[:1000]

grouped = names.groupby(['year', 'sex'])
top1000 = grouped.apply(get_top1000)

top1000
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_2948\3738172046.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top1000 = grouped.apply(get_top1000)
#                            name sex  births  year      prop
# year sex
# 1880 F   0   0             Mary   F    7065  1880  0.077643
#              1             Anna   F    2604  1880  0.028618
#              2             Emma   F    2003  1880  0.022013
#              3        Elizabeth   F    1939  1880  0.021309
#              4           Minnie   F    1746  1880  0.019188
# ...                         ...  ..     ...   ...       ...
# 2010 M   261 1677639     Camilo   M     194  2010  0.000102
# ...

# %%
top1000.reset_index(inplace=True, drop=True)
top1000
# Out:
#              name sex  births  year      prop
# 0            Mary   F    7065  1880  0.077643
# 1            Anna   F    2604  1880  0.028618
# 2            Emma   F    2003  1880  0.022013
# 3       Elizabeth   F    1939  1880  0.021309
# 4          Minnie   F    1746  1880  0.019188
# ...           ...  ..     ...   ...       ...
# 261872     Camilo   M     194  2010  0.000102
# 261873     Destin   M     194  2010  0.000102
# 261874     Jaquan   M     194  2010  0.000102
# 261875     Jaydan   M     194  2010  0.000102
# 261876     Maxton   M     193  2010  0.000102
#
# [261877 rows x 5 columns]

# %%
boys = top1000[top1000.sex == 'M']
girls = top1000[top1000.sex == 'F']

# %%
total_birth = top1000.pivot_table('births', index='year', columns='name', aggfunc='sum')

# %%
total_birth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 131 entries, 1880 to 2010
# Columns: 6868 entries, Aaden to Zuri
# dtypes: float64(6868)
# memory usage: 6.9 MB

# %%
total_birth
# Out:
# name   Aaden  Aaliyah  Aarav   Aaron  Aarush  Ab  Abagail  Abb  Abbey  Abbie  \
# year
# 1880     NaN      NaN    NaN   102.0     NaN NaN      NaN  NaN    NaN   71.0
# 1881     NaN      NaN    NaN    94.0     NaN NaN      NaN  NaN    NaN   81.0
# 1882     NaN      NaN    NaN    85.0     NaN NaN      NaN  NaN    NaN   80.0
# 1883     NaN      NaN    NaN   105.0     NaN NaN      NaN  NaN    NaN   79.0
# 1884     NaN      NaN    NaN    97.0     NaN NaN      NaN  NaN    NaN   98.0
# ...      ...      ...    ...     ...     ...  ..      ...  ...    ...    ...
# 2006     NaN   3737.0    NaN  8279.0     NaN NaN    297.0  NaN  404.0  440.0
# 2007     NaN   3941.0    NaN  8914.0     NaN NaN    313.0  NaN  349.0  468.0
# 2008   955.0   4028.0  219.0  8511.0     NaN NaN    317.0  NaN  344.0  400.0
# 2009  1265.0   4352.0  270.0  7936.0     NaN NaN    296.0  NaN  307.0  369.0
# 2010   448.0   4628.0  438.0  7374.0   226.0 NaN    277.0  NaN  295.0  324.0
#
# ...

# %%
subset = total_birth[['John', 'Harry', 'Mary', 'Marilyn']]
subset.plot(subplots=True, figsize=(12, 10), grid=False, title='Number of births per year')
plt.show()

# %%
import numpy as np

# %%
table = top1000.pivot_table('prop', index='year', columns='sex', aggfunc='sum')
table
# Out:
# sex          F         M
# year
# 1880  1.000000  0.997375
# 1881  1.000000  1.000000
# 1882  0.998702  0.995646
# 1883  0.997596  0.998566
# 1884  0.993156  0.994539
# ...        ...       ...
# 2006  0.753153  0.860368
# 2007  0.745959  0.855159
# 2008  0.740933  0.850003
# 2009  0.737290  0.845256
# 2010  0.736780  0.843156
#
# [131 rows x 2 columns]

# %%
table.plot(title='Sum of table1000.prop by year and sex', figsize=(10, 8)
           , yticks=np.linspace(0, 1.2, 13), xticks=range(1880, 2020, 10))
# Out:
# <Axes: title={'center': 'Sum of table1000.prop by year and sex'}, xlabel='year'>

# %%
df = boys[boys.year == 2010]
df
# Out:
#            name sex  births  year      prop
# 260877    Jacob   M   21875  2010  0.011523
# 260878    Ethan   M   17866  2010  0.009411
# 260879  Michael   M   17133  2010  0.009025
# 260880   Jayden   M   17030  2010  0.008971
# 260881  William   M   16870  2010  0.008887
# ...         ...  ..     ...   ...       ...
# 261872   Camilo   M     194  2010  0.000102
# 261873   Destin   M     194  2010  0.000102
# 261874   Jaquan   M     194  2010  0.000102
# 261875   Jaydan   M     194  2010  0.000102
# 261876   Maxton   M     193  2010  0.000102
#
# [1000 rows x 5 columns]

# %%
a = np.array([1, 2, 3, 4, 5])
print('sum: ', a.sum())
print('cumsum: ', a.cumsum())
# Out:
# sum:  15
# cumsum:  [ 1  3  6 10 15]

# %%
prop_cumsum = df.sort_values(by='prop', ascending=False).prop.cumsum()
prop_cumsum[:10]
# Out:
# 260877    0.011523
# 260878    0.020934
# 260879    0.029959
# 260880    0.038930
# 260881    0.047817
# 260882    0.056579
# 260883    0.065155
# 260884    0.073414
# 260885    0.081528
# 260886    0.089621
# Name: prop, dtype: float64

# %%
prop_cumsum.values.searchsorted(0.5)
# Out:
# 116

# %%
df = boys[boys.year == 1900]
in1900 = df.sort_values(by='prop', ascending=False).prop.cumsum()
in1900.values.searchsorted(0.5) + 1
# Out:
# 25

# %%
def get_quantile_count(group, q=0.5):
    group = group.sort_values(by='prop', ascending=False)
    return group.prop.cumsum().values.searchsorted(q) + 1

diversity = top1000.groupby(['year', 'sex']).apply(get_quantile_count)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_2948\2304241972.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   diversity = top1000.groupby(['year', 'sex']).apply(get_quantile_count)

# %%
diversity
# Out:
# year  sex
# 1880  F       38
#       M       14
# 1881  F       38
#       M       14
# 1882  F       38
#             ...
# 2008  M      109
# 2009  F      241
#       M      114
# 2010  F      246
#       M      117
# Length: 262, dtype: int64

# %%
diversity = diversity.unstack('sex')
diversity
# Out:
# sex     F    M
# year
# 1880   38   14
# 1881   38   14
# 1882   38   15
# 1883   39   15
# 1884   39   16
# ...   ...  ...
# 2006  209   99
# 2007  223  103
# 2008  234  109
# 2009  241  114
# 2010  246  117
#
# [131 rows x 2 columns]

# %%
diversity.plot(title='Number of popular names in top 50%', figsize=(10, 8))
plt.show()

# %%
get_last_letter = lambda x: x[-1]
last_letters = names.name.map(get_last_letter)
last_letters.name = 'last_letter'
last_letters
# Out:
# 0    0          y
#      1          a
#      2          a
#      3          h
#      4          e
#                ..
# 261  1690779    e
#      1690780    e
#      1690781    s
#      1690782    n
#      1690783    x
# Name: last_letter, Length: 1690784, dtype: object

# %%
table = names.pivot_table('births', index=last_letters, columns=['sex', 'year'], aggfunc='sum')
table
# Out:
# sex                F                                                        \
# year            1880     1881     1882     1883     1884     1885     1886
# last_letter
# a            31446.0  31581.0  36536.0  38330.0  43680.0  45408.0  49100.0
# b                NaN      NaN      NaN      NaN      NaN      NaN      NaN
# c                NaN      NaN      5.0      5.0      NaN      NaN      NaN
# d              609.0    607.0    734.0    810.0    916.0    862.0   1007.0
# e            33378.0  34080.0  40399.0  41914.0  48089.0  49616.0  53884.0
# f                NaN      NaN      NaN      NaN      NaN      NaN      NaN
# g                7.0      5.0     12.0      8.0     24.0     11.0     18.0
# h             4863.0   4784.0   5567.0   5701.0   6602.0   6624.0   7146.0
# i               61.0     78.0     81.0     76.0     84.0     92.0     85.0
# j                NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...

# %%
subtable = table.reindex(columns=[1910, 1960, 2010], level='year')
subtable.head()
# Out:
# sex                 F                            M
# year             1910      1960      2010     1910      1960      2010
# last_letter
# a            108376.0  691247.0  670605.0    977.0    5204.0   28438.0
# b                 NaN     694.0     450.0    411.0    3912.0   38859.0
# c                 5.0      49.0     946.0    482.0   15476.0   23125.0
# d              6750.0    3729.0    2607.0  22111.0  262112.0   44398.0
# e            133569.0  435013.0  313833.0  28655.0  178823.0  129012.0

# %%
subtable.sum()
# Out:
# sex  year
# F    1910     396416.0
#      1960    2022062.0
#      2010    1759010.0
# M    1910     194198.0
#      1960    2132588.0
#      2010    1898382.0
# dtype: float64

# %%
letter_prop = subtable / subtable.sum()
letter_prop
# Out:
# sex                 F                             M
# year             1910      1960      2010      1910      1960      2010
# last_letter
# a            0.273390  0.341853  0.381240  0.005031  0.002440  0.014980
# b                 NaN  0.000343  0.000256  0.002116  0.001834  0.020470
# c            0.000013  0.000024  0.000538  0.002482  0.007257  0.012181
# d            0.017028  0.001844  0.001482  0.113858  0.122908  0.023387
# e            0.336941  0.215133  0.178415  0.147556  0.083853  0.067959
# f                 NaN  0.000010  0.000055  0.000783  0.004325  0.001188
# g            0.000144  0.000157  0.000374  0.002250  0.009488  0.001404
# h            0.051529  0.036224  0.075852  0.045562  0.037907  0.051670
# i            0.001526  0.039965  0.031734  0.000844  0.000603  0.022628
# j                 NaN       NaN  0.000090       NaN       NaN  0.000769
# k            0.000121  0.000156  0.000356  0.036581  0.049384  0.018541
# ...

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 1, figsize=(10, 8))
plt.subplots_adjust(hspace=0.25)
letter_prop['M'].plot(kind='bar', rot=0, ax=axes[0], title='Male')
letter_prop['F'].plot(kind='bar', rot=0, ax=axes[1], title='Female', legend=False)
plt.show()

# %%
letter_prop = table / table.sum()
dny_ts = letter_prop.loc[['d', 'n', 'y'], 'M'].T
dny_ts.head()
# Out:
# last_letter         d         n         y
# year
# 1880         0.083055  0.153213  0.075760
# 1881         0.083247  0.153214  0.077451
# 1882         0.085340  0.149560  0.077537
# 1883         0.084066  0.151646  0.079144
# 1884         0.086120  0.149915  0.080405

# %%
dny_ts.plot(figsize=(10, 8))
plt.show()

# %%
all_names = pd.Series(top1000.name.unique())
lesley_like = all_names[all_names.str.lower().str.contains('lesl')]
lesley_like
# Out:
# 632     Leslie
# 2294    Lesley
# 4262    Leslee
# 4728     Lesli
# 6103     Lesly
# dtype: object

# %%
filltered = top1000[top1000.name.isin(lesley_like)]
filltered.groupby('name').births.sum()
# Out:
# name
# Leslee      1082
# Lesley     35022
# Lesli        929
# Leslie    370429
# Lesly      10067
# Name: births, dtype: int64

# %%
filltered.head()
# Out:
#         name sex  births  year      prop
# 632   Leslie   F       8  1880  0.000088
# 1108  Leslie   M      79  1880  0.000715
# 2462  Leslie   F      11  1881  0.000120
# 3014  Leslie   M      92  1881  0.000913
# 4512  Leslie   F       9  1882  0.000083

# %%
table = filltered.pivot_table('births', index='year', columns='sex', aggfunc='sum')
table
# Out:
# sex        F      M
# year
# 1880     8.0   79.0
# 1881    11.0   92.0
# 1882     9.0  128.0
# 1883     7.0  125.0
# 1884    15.0  125.0
# ...      ...    ...
# 2006  4166.0    NaN
# 2007  3805.0    NaN
# 2008  3022.0    NaN
# 2009  2573.0    NaN
# 2010  2060.0    NaN
#
# [131 rows x 2 columns]

# %%
table = table.div(table.sum(1), axis=0)
table.head()
# Out:
# sex          F         M
# year
# 1880  0.091954  0.908046
# 1881  0.106796  0.893204
# 1882  0.065693  0.934307
# 1883  0.053030  0.946970
# 1884  0.107143  0.892857

# %%
table.plot(style={'M': 'b-', 'F': 'r--'}, figsize=(8, 6))
plt.show()
